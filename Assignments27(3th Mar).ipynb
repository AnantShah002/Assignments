# %% [markdown]
# # Seaborn Assignment

# %% [markdown]
# ### Que 1) Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
#
# #### Ans) Five plots that we can plot using the Seaborn library
#
# * **Line plot:-** A Line Plot Is The Simplest Plot In All Plotting Types, As It Is The Visualization Of A Single Function. This Plot Helps Us To See The Relationship Between X-Axis, Y-Axis And It Also Takes Some Parameters Such As Hue, Size, Color, Etc.
#
#
# * **Countplot:-** A Count Plot Is Used To Show The Counts Of Observations In Each Categorical Bin Using Bars. This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding. Data Is Also An Optional Parameter That Takes DataFrame, Array, Or List Of Arrays, Dataset For Plotting.
#
# * **Bar Plot:-** A Bar Chart Is A Way Of Comparing A Set Of Categorical Data. It Is Better To Convert Continuous Data To Bins Before Plotting. The Bar Chart Displays Data Using Several Bars, Each Representing A Particular Category. This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding.
#
# * **Scatter Plot:-** Scatter Plot Is The Same As A Line Plot, In A Line Plot Instead Of Points Being Joined By Line Segments, The Points Are Shown Individually With A Dot, Circle, Or Any Other Shape. The Position Of Each Marker On The Horizontal And Vertical Axis Indicates Values For An Individual Data Point. This Plot Is Used To Observe Relationships Between Variables. This Method Is Accepting The Parameters X, Y  Which Take The Name Of A Variable In Data, Hue It Is An Optional Parameter It Helps To Take Column Name For Color Encoding. Marker Is A Parameter That Is Used To Change The Shape Of The Point Which Is Shown In The Plot.
#
# * **Pair Plot:-** Pair Plot Creates A Grid Of Axis Such That Each Numeric Variable In Data Will Create A Plot Between Each Other The Y-Axis Across A Single Row And The X-Axis Across A Single Column. The Diagonal Plots Are A Univariate Distribution Plot That Helps To Draw The Marginal Distribution Of The Data In Each Column. A Pair Plot Pairwise Relationships With Other Columns In The Data Frame And Also Plot Pair Plot With Itself.

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Line Plot
sns.lineplot(x=tips.day,y=tips.total_bill)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
# Count Plot
sns.countplot(x=tips["sex"],data=tips)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
# Bar Plot
sns.barplot(x=tips["smoker"] ,y=tips.total_bill,data=tips)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='total_bill'>

# %%
# scatter plot
sns.scatterplot(x=tips.total_bill,y=tips.tip)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
#  Pair Plot
sns.pairplot(data=tips)

# %% [markdown]
# ### Que 2) Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
#
# * Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x=fmri.timepoint,y=fmri.signal)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# ### Que 3) Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.
#
# * Note: pclass, age, and fare are columns in the titanic dataset.

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x = titanic['pclass'], y = titanic['age'])
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x = titanic['pclass'], y = titanic['fare'])
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# ### Que 4) Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
diam = sns.load_dataset("diamonds")
diam.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.histplot(x=diam.price,hue=diam.cut)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %% [markdown]
# ### Que 5) Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue="species")

# %% [markdown]
# ### Que 6) Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flig=sns.load_dataset("flights")
flig.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.heatmap(flig.pivot('month', 'year', 'passengers'))
# Out:
# /tmp/ipykernel_4299/437679315.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(flig.pivot('month', 'year', 'passengers'))
# <AxesSubplot: xlabel='year', ylabel='month'>
